# %% [markdown]
# ***allgeimeine Zitierform***
#
# qiime "plugin name" citations

# %%
qiime <plugin-name> citations

# %% [markdown]
# ***Citation for 4) Filtering***

# %%
! qiime taxa barplot --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# No citations found.

# %%
! qiime feature-table summarize --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# No citations found.

# %%
! qiime taxa filter-table --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# No citations found.

# %%
! qiime feature-table summarize --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# No citations found.

# %%
! qiime taxa filter-seqs --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# No citations found.

# %%
! qiime feature-table tabulate-seqs --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# % use `qiime tools citations` on a QIIME 2 result for complete list
#
# @article{key0,
#  author = {NCBI Resource Coordinators},
#  doi = {10.1093/nar/gkw1071},
#  journal = {Nucleic Acids Research},
#  number = {D1},
#  pages = {D12-D17},
#  title = {Database Resources of the National Center for Biotechnology Information},
#  volume = {45},
#  year = {2017}
# }
#
# @article{key1,
#  author = {Johnson, Mark and Zaretskaya, Irena and Raytselis, Yan and Merezhuk, Yuri and McGinnis, Scott and Madden, Thomas L.},
#  doi = {10.1093/nar/gkn201},
#  journal = {Nucleic Acids Research},
#  number = {suppl_2},
#  pages = {W5-W9},
# ...

# %% [markdown]
# ***5) Alpha Citations***

# %%
! qiime diversity alpha-rarefaction --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# No citations found.

# %%
! qiime diversity core-metrics --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# No citations found.

# %%
! qiime diversity alpha-group-significance --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# % use `qiime tools citations` on a QIIME 2 result for complete list
#
# @article{key0,
#  author = {Kruskal, William H and Wallis, W Allen},
#  doi = {10.1080/01621459.1952.10483441},
#  journal = {Journal of the American statistical Association},
#  number = {260},
#  pages = {583--621},
#  publisher = {Taylor & Francis},
#  title = {Use of ranks in one-criterion variance analysis},
#  volume = {47},
#  year = {1952}
# }

# %%
! qiime diversity alpha-correlation --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# % use `qiime tools citations` on a QIIME 2 result for complete list
#
# @article{key0,
#  author = {Pearson, Karl},
#  doi = {https://doi.org/10.1098/rspl.1895.0041},
#  journal = {Proceedings of the Royal Society of London},
#  pages = {240--242},
#  publisher = {JSTOR},
#  title = {Note on regression and inheritance in the case of two parents},
#  volume = {58},
#  year = {1895}
# }
#
# @article{key1,
#  author = {Spearman, Charles},
#  doi = {https://doi.org/10.2307/1422689},
#  journal = {The American journal of psychology},
#  number = {1},
#  pages = {72--101},
#  publisher = {JSTOR},
# ...

# %% [markdown]
# ***Beta diversity***

# %%
# !qiime diversity filter-distance-matrix --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# No citations found.

# %%
! qiime diversity beta-group-significance --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# % use `qiime tools citations` on a QIIME 2 result for complete list
#
# @article{key0,
#  author = {Anderson, Marti J},
#  doi = {https://doi.org/10.1111/j.1442-9993.2001.01070.pp.x},
#  journal = {Austral ecology},
#  number = {1},
#  pages = {32--46},
#  publisher = {Wiley Online Library},
#  title = {A new method for non-parametric multivariate analysis of variance},
#  volume = {26},
#  year = {2001}
# }

# %%
# !qiime longitudinal pairwise-distances --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# % use `qiime tools citations` on a QIIME 2 result for complete list
#
# @article{key0,
#  author = {Bokulich, Nicholas A. and Dillon, Matthew R. and Zhang, Yilong and Rideout, Jai Ram and Bolyen, Evan and Li, Huilin and Albert, Paul S. and Caporaso, J. Gregory},
#  doi = {10.1128/mSystems.00219-18},
#  journal = {mSystems},
#  number = {6},
#  pages = {e00219-18},
#  title = {q2-longitudinal: Longitudinal and Paired-Sample Analyses of Microbiome Data},
#  volume = {3},
#  year = {2018}
# }

# %%
! qiime diversity adonis --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# % use `qiime tools citations` on a QIIME 2 result for complete list
#
# @article{key0,
#  author = {Anderson, Marti J},
#  doi = {https://doi.org/10.1111/j.1442-9993.2001.01070.pp.x},
#  journal = {Austral ecology},
#  number = {1},
#  pages = {32--46},
#  publisher = {Wiley Online Library},
#  title = {A new method for non-parametric multivariate analysis of variance},
#  volume = {26},
#  year = {2001}
# }
#
# @manual{key1,
# ...

# %% [markdown]
# ***Aromas***

# %%
# !qiime tools export --citations
# Out:
# Usage: qiime tools export [OPTIONS]
#
#   Exporting extracts (and optionally transforms) data stored inside an
#   Artifact or Visualization. Note that Visualizations cannot be transformed
#   with --output-format
#
# Options:
#   --input-path ARTIFACT/VISUALIZATION
#                         Path to file that should be exported        [required]
#   --output-path PATH    Path to file or directory where data should be
#                         exported to                                 [required]
#   --output-format TEXT  Format which the data should be exported as. This
#                         option cannot be used with Visualizations
#   --help                Show this message and exit.
#
#                     There was a problem with the command:
#  (1/1?) No such option: --citations

# %% [markdown]
# ***Differential abundance***

# %%
!  qiime composition ancombc --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# % use `qiime tools citations` on a QIIME 2 result for complete list
#
# @article{key0,
#  author = {Lin, Huang and Peddada, Shyamal Das},
#  doi = {10.1038/s41467-020-17041-7},
#  journal = {Nature communications},
#  number = {1},
#  pages = {3514},
#  publisher = {Nature Publishing Group UK London},
#  title = {Analysis of compositions of microbiomes with bias correction},
#  url = {https://www.nature.com/articles/s41467-020-17041-7},
#  volume = {11},
#  year = {2020}
# }

# %%
! qiime composition da-barplot --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# No citations found.

# %%
! qiime taxa collapse --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# No citations found.

# %%
! qiime composition tabulate --citations
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# No citations found.

# %%
# !qiime info
# Out:
# System versions
# Python version: 3.10.14
# QIIME 2 release: 2025.7
# QIIME 2 version: 2025.7.0
# q2cli version: 2025.7.0
#
# Installed plugins
# alignment: 2025.7.0
# annotate: 2025.7.0
# assembly: 2025.7.0
# boots: 0.0.1+162.g946b12e
# composition: 2025.7.0
# cutadapt: 2025.7.0
# dada2: 2025.7.0
# deblur: 2025.7.0
# demux: 2025.7.0
# diversity: 2025.7.0
# diversity-lib: 2025.7.0
# emperor: 2025.7.0
# feature-classifier: 2025.7.0
# feature-table: 2025.7.0
# fondue: 2025.7.0
# fragment-insertion: 2025.7.0
# kmerizer: 0.0.1+37.gfd404f7
# longitudinal: 2025.7.0
# metadata: 2025.7.0
# phylogeny: 2025.7.0
# quality-control: 2025.7.0
# quality-filter: 2025.7.0
# rescript: 2025.7.0
# sample-classifier: 2025.7.0
# sourmash: 0.0.0
# stats: 2025.10.0.dev0+3.g0e345b9
# taxa: 2025.7.0
# types: 2025.7.0
# vizard: 2025.10.0.dev0+13.g6acebbb
# vsearch: 2025.7.0
#
# Application config directory
# /opt/conda/var/q2cli
#
# Config
# Config Source: /opt/conda/etc/qiime2_config.toml
#
# Getting help
# ...

# %%
import pandas as pd

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2
