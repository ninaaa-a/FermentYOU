# %%
import os
import pandas as pd
from qiime2 import Visualization
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data_dir = 'fermentyou_data'

# %%
#feature data metadata
df_meta = pd.read_csv('fermentyou_data/20250913_metadata_ITS.tsv', sep='\t', index_col=0)
df_meta.head(2)
# Out:
#                         label_barcode1 label_barcode2      created_date  \
# sample ID
# 366291_386-LP4-ITS-0386   GGAAGTGAAGTT   ATTTGCTTTGCC  16.10.2024 14:59
# 366291_387-LP4-ITS-0387   GATCGGGTCGGA   GTGACCCTGTCA  16.10.2024 14:59
#
#                         amplicon     unique_id   sample_id  person-id plate  \
# sample ID
# 366291_386-LP4-ITS-0386      ITS  LP4-ITS-0386  1820-d21-1     1820.0    P5
# 366291_387-LP4-ITS-0387      ITS  LP4-ITS-0387   1725-d7-1     1725.0    P5
#
#                         plate_position  amplicon_conc DNA_extraction_plate  \
# sample ID
# 366291_386-LP4-ITS-0386            B01         6.7035                DNA59
# 366291_387-LP4-ITS-0387            C01         7.8515                DNA59
#
#                             project   project_2 sample_type   day hand
# sample ID
# 366291_386-LP4-ITS-0386  highschool  highschool   sourdough  21.0  NaN
# 366291_387-LP4-ITS-0387  highschool  highschool   sourdough   7.0  NaN

# %%
#feature data personal environment
df_envir = pd.read_csv('fermentyou_data/20250914_metadata_personal_environmental_sensory_details.tsv', sep='\t', index_col=0)
df_envir.head(2)
# Out:
#                  start_time   completion_time background ethical_agreement  \
# person-id
# 1701       6.18.24 23:34:47  6.18.24 23:37:55    sterile          I agree.
# 1702       6.18.24 23:37:40  6.18.24 23:42:32    sterile          I agree.
#
#           sd_bake_experience sd_bake_last_time yeast_bake_experience  \
# person-id
# 1701                      no               NaN                   yes
# 1702                      no               NaN                   yes
#
#           yeast_bake_last_time      sd_stor_loc  sd_stor_temp  ...  \
# person-id                                                      ...
# 1701                 4.18.2024  kitchen counter          23.0  ...
# 1702                05.01.2023         cupboard          25.0  ...
#
#            animal_score_D28  chemical_score_D28  body_odour_score_D28  \
# person-id
# 1701                    0.0                 2.0                   0.0
# 1702                    0.0                 0.0                   0.0
#
# ...

# %%
! qiime feature-table tabulate-seqs \
    --i-data $data_dir/filtered-dada1-rep-seqs-highschool.qza \
    --o-visualization $data_dir/filtered-dada1-rep-seqs-highschool.qzv
Visualization.load(f"{data_dir}/filtered-dada1-rep-seqs-highschool.qzv")

#it yields around 20'000 sequences that have a lentgth of 50-300bp
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: fermentyou_data/filtered-dada1-rep-seqs-highschool.qzv
# <visualization: Visualization uuid: 47d42ee6-4aa9-4ea7-bbd3-3fb6ffa54e68>

# %%
! qiime quality-filter q-score \
    --i-demux $data_dir/filtered-dada1-rep-seqs-highschool.qza \
    --p-min-quality 30 \
    --p-min-length-fraction 0.9 \
    --o-filtered-sequences $data_dir/filtered_highschool_qc.qza \
    --o-filter-stats $data_dir/filtered_highschool_qc_stats.qza
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Usage: qiime quality-filter q-score [OPTIONS]
#
#   This method filters sequence based on quality scores and the presence of
#   ambiguous base calls.
#
# Inputs:
#   --i-demux ARTIFACT SampleData[SequencesWithQuality]¹ |
#     SampleData[PairedEndSequencesWithQuality]² |
#     SampleData[JoinedSequencesWithQuality]³
#                          The demultiplexed sequence data to be quality
#                          filtered.                                  [required]
# Parameters:
#   --p-min-quality INTEGER
#                          The minimum acceptable PHRED score. All PHRED scores
# ...

# %%
! qiime demux summarize \
    --i-data $data_dir/filtered_highschool_qc.qza \
    --o-visualization $data_dir/filtered_highschool_qc.qzv
Visualization.load(f"{data_dir}/filtered_highschool_qc.qzv")
