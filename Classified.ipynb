# %%
import os
import pandas as pd
from qiime2 import Visualization
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
Data_classified = 'Data/classified'

# %%
! qiime metadata tabulate \
    --m-input-file $Data_classified/taxonomy.qza \
    --o-visualization $Data_classified/taxonomy.qzv
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: Data/classified/taxonomy.qzv

# %%
Visualization.load(f"{Data_classified}/taxonomy.qzv")
# Out:
# <visualization: Visualization uuid: a2da0523-e69e-479e-919c-8d9fcb60b890>

# %% [markdown]
# Open the sequences so that we can search the unknown in Blast

# %% [markdown]
# Searched features and the assignment according to Blast:
# 00092136fb6308db988563134d57777a: Uncultured fungus clone
# 005d4ae8df0f1bc2c174c851c68dc25a: Uncultured fungus clones & various bacteria
# 008e408c97e4f7776e6a5887a3563886: Triticum urartu
# 00c39aaa2531df1cf9813ae3354fce60: Uncultured fungi or different viruses
# 00ed9f91c3f1ccc528cd835fa9b1f933: Triticum aestivum
# 00ef928c889515b9a5c35686cca559b6: Triticum aestivum
# 010c0d1738ced4854afd7748ab5ce1c8: uncultured fungus clone
# 01663efd5f84cd7a888002f9229bdf9e: uncultured fungus clone
# 016baf219325ca75d212f8dcd148041e: Cudonia lutea (ascomycete)
# 01a0f0ce14f0571031e772e8a4b5bb0f: Triticum aestivum
# 01c3aafcb138dd8b75ce9a7af7720654: Cucumis melo (cantaloupe)
# 01e261e6d4eb73640083c98841282013: many different things
# 01eaee783d3263638e5d8420010a0da5: Triticum aestivum
# 021fc4b151c16bb2afda87555cd28691: many different things

# %%
Visualization.load('Data/visualization/filtered-dada1-rep-seqs-highschool.qzv')
# Out:
# <visualization: Visualization uuid: a4967253-742c-488a-9185-7a070b382115>
